# %% [markdown]
# <a href="https://colab.research.google.com/github/yasnilamw/MSIB-K2-KelasAwanPintar/blob/main/29_10_24(Student)SL_05_Data_Aquisition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Materials
# - Scraping | BeautifulSoup4 | website legal untuk scraping
#   - Prequisite: Basic HTML dan CSS Selector
#   > Tetapi untuk materi ini cukup ketahui cara kerja dan gambaran umumnya saja. Jika tertarik lebih dalam mengenai HTML dan CSS (terutama CSS Selector) untuk Web Scraping, dapat menggunakan referensi berikut untuk belajar tambahan:
#     - [Playlist Dasar HTML by WPU](https://www.youtube.com/playlist?list=PLFIM0718LjIVuONHysfOK0ZtiqUWvrx4F) | Video
#     - [Dasar HTML by Petani Kode](https://www.petanikode.com/tutorial/html/) | Artikel
#     - [Dasar HTML by W3School](https://www.w3schools.com/html/) | Artikel dan Lab Hands On
#     - [CSS Selector by WPU](https://www.youtube.com/watch?v=0KLwWyQyMQo&list=PLFIM0718LjIUBrbm6Gdh6k7ZUvPIAZm7p&index=7) | Video
#     - [CSS Selector by W3School](https://www.w3schools.com/cssref/css_selectors.asp) | Artikel dan Lab Hands On
#
# - Import data dari file txt
# - Bag of Word (sebelum preprocessing)
# - Preprocessing
#   - Tokenization
#   - Stemming
#   - Lemmatization
# - Bag of Word (Setelah Preprocessing)
#
# #1. Web Scraping

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import requests # Library untuk melakukan request dari website tertentu
from bs4 import BeautifulSoup # Library untuk ekstaraksi konten dalam website

# %% [markdown]
# Untuk website yang akan kita gunakan untuk scraping adalah website warstek.com. Website ini milik Coach Wayan dan sudah mendapatkan persetujuan untuk dijadikan objek web scraping :)

# %%
result = requests.get("https://warstek.com/kabel-laut/")

# %%
result
# Out:
# <Response [200]>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Mengubah Encoding menjadi utf-8 | Jika tidak dikonversi ke utf-8 untuk karakter khusus
# seperti ",'/- dll akan menjadi karakter yang sulit dipahami
# Out:
# 'utf-8'

# %%
wp = BeautifulSoup(result.text, "html.parser")

# %% [markdown]
# Mengambil bagian html dengan tag 'p' paling awal (paragraph)
# Silakan klik link wartek yang mengarah ke artikel https://warstek.com/kabel-laut/
#
# Nah, pada artikel tersebut kita akan menemukan tag 'p' dengan klik kanan pada artikel lalu pilih 'Inspect'
#
# ![download.png](data:image/png;base64,...)
#
# Lalu akan muncul seperti berikut,
#
# ![image.png](data:image/png;base64,...)
#
# Tampilan tersebut merupakan struktur dasar dari halaman web yang berupa HTML. Struktur tersebut memiliki beberapa elemen dengan fungsinya masing - masing yang ditandai dengan adanya tag seperti `<p>`, `<img>`, `<a>`, `<table>`, `<div>` dll.
#
# Karena yang akan kita ambil adalah bagian konten teks dan konten teks tersebut tersimpan pada tag `<p>` (paragraph), maka kita akan menggunakan tag tersebut sebagai selector atau penanda.
#
# Nah, pada bagian Element itu akan muncul html untuk tag 'p' tadi, kalo mau cepat nyarinya bisa dengan pencarian cepat dengan tekan CRTL + f lalu ketik p, maka akan lebih cepat nyarinya, atau bisa juga telusuri satu-satu. Nanti akan ktemu tag 'p' seperti dibawah ini:
#
# Nahh, kira-kira demikian proses buat dapetin tag 'p'-nya.

# %% [markdown]
# Nah, pada bagian Element itu akan muncul html untuk tag 'p' tadi, kalo mau cepat nyarinya bisa dengan pencarian cepat dengan tekan CRTL + f lalu ketik p, maka akan lebih cepat nyarinya, atau bisa juga telusuri satu-satu. Anati akan ktemu tag 'p' seperti dibawah ini:
#
# ![image.png](data:image/png;base64,...)
#
# Nahh, kira-kira demikian proses buat dapetin tag 'p'-nya.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Mengambil bagian html dengan tag p paling awal (paragraph)
# Out:
# <p>Sains dan Teknologi yang Seru dan Menyenangkan</p>

# %%
# Mengambil bagian html dengan tag p paling awal, tapi hanya value-nya saja.
# Out:
# 'Sains dan Teknologi yang Seru dan Menyenangkan'

# %%
# Out:
# 'Sains dan Teknologi yang Seru dan Menyenangkan'

# %%
# Mengambil bagian html dengan tag p (secara keseluruhan)
# Out:
# [<p>Sains dan Teknologi yang Seru dan Menyenangkan</p>,
#  <p>Pada hari Minggu lalu (19 September 2021), terjadi gangguan jaringan internet pada Telkomsel dan Indihome. Gangguan tersebut menyebabkan penurunan kualitas layanan TelkomGroup baik <em>fixed</em> maupun <em>mobile broadband</em> di beberapa wilayah Indonesia. Di masa pandemi yang menuntut orang untuk berada di rumah seperti ini, gangguan internet tentu menjadi masalah besar. Berbagai kegiatan penting seperti Seleksi Kompetensi Dasar (SKD) CPNS mengalami penundaan. Netizen pun banyak berkomentar negatif terkait hal ini. Saat artikel ini dirilis, gangguan tersebut mungkin belum benar-benar terselesaikan.</p>,
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#lengkapilah! sesuai kode diatas!
full_text = []
for paragraf in wp.___('p'):
  full_text.___(paragraf.getText())

full_text
# Out:
# ['Sains dan Teknologi yang Seru dan Menyenangkan',
#  'Pada hari Minggu lalu (19 September 2021), terjadi gangguan jaringan internet pada Telkomsel dan Indihome. Gangguan tersebut menyebabkan penurunan kualitas layanan TelkomGroup baik fixed maupun mobile broadband di beberapa wilayah Indonesia. Di masa pandemi yang menuntut orang untuk berada di rumah seperti ini, gangguan internet tentu menjadi masalah besar. Berbagai kegiatan penting seperti Seleksi Kompetensi Dasar (SKD) CPNS mengalami penundaan. Netizen pun banyak berkomentar negatif terkait hal ini. Saat artikel ini dirilis, gangguan tersebut mungkin belum benar-benar terselesaikan.',
# ...

# %% [markdown]
# > Terlihat bahwa link text masih banyak whitespace atau spasi kosong yang terdapat pada list sehingga perlu dibersihkan juga.

# %%
# Menghapus None dari list full_text sekaligus membersihkan elemen list dari whitespace menggunakan fungsi strip()
# List Comprehension
full_text = [paragraf.strip() for paragraf in full_text if paragraf != ""]
full_text
# Out:
# ['Sains dan Teknologi yang Seru dan Menyenangkan',
#  'Pada hari Minggu lalu (19 September 2021), terjadi gangguan jaringan internet pada Telkomsel dan Indihome. Gangguan tersebut menyebabkan penurunan kualitas layanan TelkomGroup baik fixed maupun mobile broadband di beberapa wilayah Indonesia. Di masa pandemi yang menuntut orang untuk berada di rumah seperti ini, gangguan internet tentu menjadi masalah besar. Berbagai kegiatan penting seperti Seleksi Kompetensi Dasar (SKD) CPNS mengalami penundaan. Netizen pun banyak berkomentar negatif terkait hal ini. Saat artikel ini dirilis, gangguan tersebut mungkin belum benar-benar terselesaikan.',
# ...

# %%
full_text = ' '.join(full_text)
full_text
# Out:
# 'Sains dan Teknologi yang Seru dan Menyenangkan Pada hari Minggu lalu (19 September 2021), terjadi gangguan jaringan internet pada Telkomsel dan Indihome. Gangguan tersebut menyebabkan penurunan kualitas layanan TelkomGroup baik fixed maupun mobile broadband di beberapa wilayah Indonesia. Di masa pandemi yang menuntut orang untuk berada di rumah seperti ini, gangguan internet tentu menjadi masalah besar. Berbagai kegiatan penting seperti Seleksi Kompetensi Dasar (SKD) CPNS mengalami penundaan. Netizen pun banyak berkomentar negatif terkait hal ini. Saat artikel ini dirilis, gangguan tersebut mungkin belum benar-benar terselesaikan. Gangguan tersebut disebabkan oleh masalah pada sistem komunikasi kabel laut JaSuKa (Jawa, Sumatera dan Kalimantan) ruas Batam-Pontianak. Telkom memperkirakan proses perbaikan kabel laut yang terganggu akan berlangsung sekitar sebulan. Meski begitu, Telkom mencoba berbagai alternatif agar jaringan internet tetap dapat berjalan sebaik mungkin, meski tentu ti
# ...

# %% [markdown]
# ##2. Crawling data with SNSCRAPE

# %% [markdown]
# Social Networking Services (SNS) digunakan untuk mengambil data dari media sosial. data yang diambil/yang bisa diekstrak berupa query profil pengguna, hastag, hasil pencarian ataupun elemen lainnya yang ada di jejaring sosial.
# Pada kesempatan kali ini kita akan mencoba mengambil data pada media sosial dengan menggunakan library snscrape. Diantaranya facebook, Instagram, Telegram, dan Twitter

# %% [markdown]
# # Twitter

# %%
#install package yang dibutuhkan
# !pip install dataclasses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install DateTime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 25.9 MB/s eta 0:00:00
# ...

# %%
# !pip install typing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 KB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26323 sha256=702b934d0180daa90719449400a64cd46bdf0b9c57d222c091ad52926e05db1c
#   Stored in directory: /root/.cache/pip/wheels/5e/5d/01/3083e091b57809dad979ea543def62d9d878950e3e74f0c930
# Successfully built typing
# ...

# %%
# !pip install -q snscrape==0.3.4

# %%
# import library yang dibutuhkan
import pandas as pd
import os
from datetime import date
import bs4
import snscrape

# %%
today = date.today()
end_date = today

# %%
search_topic = 'chatGPT'
from_date = '2023-01-01'

# %% [markdown]
# ##Total jumlah tweets dari hasil pencarian

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Lengkapi code dibawah ini dengan melihat gambar diatas
os.system(f"snscrape --since {from_date} twitter-search '{search_topic} until:{end_date}' > result-tweets.txt")
if os....("result-tweets.txt").st_size == 0:
  counter = 0
else:
  df = ...read_csv('result-tweets.txt', ...=['link'])
  counter = df.size

print('Total Tweets : '+ str(counter))
# Out:
# Total Tweets : 7

# %% [markdown]
# ##Mengekstrak Topik tujuan dari hasil pencarian

# %%
max_results = 100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Lengkapi code dibawah ini dengan melihat gambar diatas
extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {......} --since {......} twitter-search '{.....} until:{end_date}' > extracted-tweets.txt"
os.system(.......)
if os.stat("extracted-tweets.txt").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('extracted-tweets.txt', names=['content'])
  for row in df['content'].iteritems():
    print(row)
# Out:
# (("'@ukostello Totally agree.....  ChatGPT seems like a great technology in a vacuum", ' but the answers it gives on controversial issues are clearly programmed to be one-sided.  \\n\\nChatGPT is an improved Google'), ' with all the censorship and bias that Google "provides".\'')
# (("'chatGPT結構エラーおきるなぁ'", nan), nan)
# (("'“Used in the right way", ' #ChatGPT can be a friend to the classroom and an amazing tool for our students.”\\n\\nKathy Hirsh-Pasek and @blinkoffe discuss how the bot could foster deeper'), " more engaged learning in the classroom. @KathyandRo1 #EdTech #EdChat \\nhttps://t.co/zjC8q8EbZX'")
# (('\'"Google CEO Says Its ChatGPT Rival Coming Soon as a ‘Companion’\\xa0to Search" https://t.co/iR41IyQx4h\'', nan), nan)
# (("'ChatGPTやばいすね。すご。'", nan), nan)
# (("'Analysis: unequal treatment of demographic groups by ChatGPT\\n\\nResult: insanely woke https://t.co/07Xnq4ImrQ'", nan), nan)
# ...

# %% [markdown]
# ---
#
#
# Mengekstrak tweet dari users
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Lengkapi code dibawah dengan melihat jawaban pada gambar diatas!
...................
............................................................................................................................
..................
if os.stat("user-tweets.txt").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('user-tweets.txt', names=['content'])
  for row in df['content'].iteritems():
    print(row)
# Out:
# (0, '\'@MartinSantosR @agaviriau @carolinasotolos De acuerdo! Me causa impotencia ver cómo el gobierno parece ignorarlos. Petro hasta ahora no ha dicho siquiera si va a revisar o tener en cuenta lo dicho por Alejandro. Dijo que el documento de AG era "viejo" y la prensa lo usó para "sabotear". (Para tu lista de tuits @FLIP_org)\'')
# (1, "@HOLLMANMORRIS @agaviriau @petrogustavo Por un lado ya dijo que como él ganó, entonces la reforma va porque va, sin siquiera saber la ciudadanía el texto oficial. Sin mostrar un poco de asertividad o darle importancia a la opinión de Alejandro. Pa' rematar esto👇🏼 (que a Ud le alegrará). ¿Disenso? https://t.co/hIG5jHqlDl")
# (2, "'https://t.co/RL8lJwdkLA'")
# (3, "'@DarioSDimate NUNCA.'")
# (4, "'Vean a Petro en modo tirano. Nada que hacer")
# (5, "'@Morunno @agaviriau @petrogustavo Lo que dijo Petro en ese tuit fue una brutalidad")
# (6, "'@agaviriau @petrogustavo Te deseo suerte tratando de razonar con alguien que piensa así. En serio")
# ...

# %% [markdown]
# ---
# **Menampilkan Kolom** 'date, 'id','content','username','like_count','retweet_count
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Import library disini ya. Tulis dan sesuaikan dengan isi gambar diatas

# %%
tweet_df = pd.DataFrame(
    df, columns=["date", 'id','content','username']
)

# %% [markdown]
# ---
# Menarik data di twitter

# %%
scraper = sntwitter.TwitterSearchScraper('#bjorka')

# %%
for tweet in scraper.get_items():
  break

# %%
tweet
# Out:
# Tweet(url='https://twitter.com/ketawaterus3/status/1621131170489716738', date=datetime.datetime(2023, 2, 2, 12, 59, 24, tzinfo=datetime.timezone.utc), content='Iya Mbak iya\n\n#meme #ngakak #lucu #Kocak #TikTok #malamjumatcrot #Bjorka #kkndesapenari #NoBraDay2022 #ceweksange #malamjumat https://t.co/LoLqGK8R3r', id=1621131170489716738, username='ketawaterus3', outlinks=[], outlinksss='', tcooutlinks=[], tcooutlinksss='')

# %% [markdown]
# ---
# Mengekstrak Data Twitter
#
#
# ---
#
#
#
# ---

# %%
scraper = sntwitter.TwitterSearchScraper('#bjorka')

tweets = []

for i,  tweet in enumerate(scraper.get_items()):
  data = [
    tweet.date,
    tweet.id,
    tweet.content,
    tweet.username
  ]
  tweets.append(data)
  if i > 100:
    break

# %%
tweets

# %%
# Mengubah kedalam dataframe
tweet_df = pd.DataFrame(
    tweets, columns=['date','id','username','content']
)

# %%
tweet_df
# Out:
#                          date                   id  \
# 0   2023-02-02 12:59:24+00:00  1621131170489716738
# 1   2023-02-01 10:20:40+00:00  1620728832478298112
# 2   2023-01-18 03:00:00+00:00  1615544508933890049
# 3   2023-01-31 09:14:06+00:00  1620349692583477248
# 4   2023-01-30 12:06:52+00:00  1620030785867911168
# ..                        ...                  ...
# 97  2023-01-19 09:49:21+00:00  1616009911036702720
# 98  2023-01-19 00:07:47+00:00  1615863554086961152
# 99  2023-01-18 19:24:14+00:00  1615792199555514370
# 100 2023-01-18 10:29:33+00:00  1615657641493278720
# 101 2023-01-18 03:00:00+00:00  1615544508933890049
#
#                                               username          content
# 0    Iya Mbak iya\n\n#meme #ngakak #lucu #Kocak #Ti...     ketawaterus3
# 1    Biar Merata Harumnya\n\n#meme #ngakak #lucu #K...     ketawaterus3
# 2    📢 𝐁𝐋𝐀𝐂𝐊𝐏𝐈𝐍𝐊 𝐖𝐎𝐑𝐋𝐃 𝐓𝐎𝐔𝐑 [𝐁𝐎𝐑𝐍 𝐏𝐈𝐍𝐊] 𝐒𝐈𝐍𝐆𝐀𝐏𝐎𝐑𝐄 -...     livenationsg
# ...

# %%
tweet_df.to_csv('hasil-bjorka.csv')

# %% [markdown]
# # Adding to Progress Bar

# %%
scraper = sntwitter.TwitterSearchScraper('#bjorka')

tweets = []

n_tweets = 1_000
for i,  tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
    tweet.date,
    tweet.id,
    tweet.content,
    tweet.username
  ]
  tweets.append(data)
  if i > n_tweets:
    break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
tweet_df = pd.DataFrame(
    tweets, columns=['date','id','username','content']
)

# %%
tweet_df
# Out:
#                           date                   id  \
# 0    2023-02-02 12:59:24+00:00  1621131170489716738
# 1    2023-02-01 10:20:40+00:00  1620728832478298112
# 2    2023-01-18 03:00:00+00:00  1615544508933890049
# 3    2023-01-31 09:14:06+00:00  1620349692583477248
# 4    2023-01-30 12:06:52+00:00  1620030785867911168
# ...                        ...                  ...
# 997  2022-10-17 07:40:10+00:00  1581912939711565825
# 998  2022-10-17 07:10:17+00:00  1581905422784827392
# 999  2022-10-17 06:40:09+00:00  1581897837909983233
# 1000 2022-10-17 06:10:16+00:00  1581890317346742273
# 1001 2022-10-17 05:40:12+00:00  1581882749513699328
#
#                                                username          content
# 0     Iya Mbak iya\n\n#meme #ngakak #lucu #Kocak #Ti...     ketawaterus3
# 1     Biar Merata Harumnya\n\n#meme #ngakak #lucu #K...     ketawaterus3
# 2     📢 𝐁𝐋𝐀𝐂𝐊𝐏𝐈𝐍𝐊 𝐖𝐎𝐑𝐋𝐃 𝐓𝐎𝐔𝐑 [𝐁𝐎𝐑𝐍 𝐏𝐈𝐍𝐊] 𝐒𝐈𝐍𝐆𝐀𝐏𝐎𝐑𝐄 -...     livenationsg
# ...

# %% [markdown]
# #3. Crawling Data From Twitter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#import Library
 #import path directory
 #import file csv
 #package untuk crawling data pada tweeter
 #untuk visualisasi

# %%
#emanggil data dari tweeter menggunakan API
access_token = "3760416139-MLn5ifjLKCSXh4dWrgmOsSpQ6lYvefNkbQNuM35"
access_token_secret ="KsKpKqYwCli8YDNJg15y8ZW0quVlfGwrUCrOX4xLZHMaE"
consumer_key ="gchYjFhHc48sIveGC8fMVa2Sw"
consumer_secret="F4wR4cp8CIcAhkUgVFtrOZDg9CDKaroN9O0dkh2vSxgubnoKCb"

# %% [markdown]
# cara mengambil token data pada tweeter dengan API:
#
# https://youtu.be/ECPjw0w-qK0

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret) #memanggil data concumer_key, consumer_secret
auth.set_access_token(access_token, access_token_secret) #memanggil access_token, access_token_secret
api = tw.API(auth, wait_on_rate_limit=True) #autentifikasi ke twitter

# %% [markdown]
# pencarian topik

# %%
search_words = "kampusmerdeka"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Lengkapilah code berikut sesuaikan pada kode diatas!

csvFile = ___('Shopeepay.csv', 'a')
#Use csv Writer
csvWriter = csv.__(csvFile)

ids = set()
____.writerow(['timetweet','isitweet','favcount', 'retwcount','id','name'])

csvFile.___()

# %%
csvFile = open('Shopeepay.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)

ids = set()

for tweet in  tw.Cursor(api.search,
                   q=search_words,
                   date ='2020-12-12',
                   lang='id',
                   tweet_mode = 'extended').items(90000):
  #if (not tweet.retweeted) and ('RT @' not in tweet.full_text):
    #Write a row to the csv file/ I use encode utf-8
    csvWriter.writerow([tweet.created_at, tweet.full_text.encode('utf_8'), tweet.favorite_count, tweet.retweet_count, tweet.id, tweet.user.screen_name])
    #print "...%s tweets downloaded so far" % (len(tweet.id))
    ids.add(tweet.id) # add new id
    #print ("number of unique ids seen so far: {}",format(len(ids)))
csvFile.close()

# %%
#with open(path, 'rb') as f: contens = f.read()
df = pd.read_csv('Shopeepay.csv')
df.head()
# Out:
#              timetweet                                           isitweet  \
# 0  2022-08-12 03:12:22  b'Diskon hingga Rp100.000 beli tiket event pak...
# 1  2022-08-12 03:06:35  b'OPEN JASA PENCAIRAN GESTUN/CV LIMIT SHOPEEPA...
# 2  2022-08-12 03:01:50  b'Mun rumah bisa shopeepaylater 7 turunan mah ...
# 3  2022-08-12 02:59:01  b'\xf0\x9f\x92\xb5 1\nYuk yang mau Gestun bisa...
# 4  2022-08-12 02:34:54  b'\xe2\x9c\xa8Proof\xe2\x9c\xa8\nTransaksi ges...
#
#    favcount  retwcount                   id           name
# 0         0          0  1557927948183048194       loketcom
# 1         0          0  1557926493199937536  Wegethershop_
# 2         0          0  1557925299416809472       jauhann_
# 3         0          0  1557924589480869889       beslanja
# 4         0          0  1557918519295373312   hellowjunnie

# %%
len(df.index)
# Out:
# 364

# %% [markdown]
# ## 4. Create Data JSON

# %%
#Import Modul
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd

# %%
data_json = "https://jsonplaceholder.typicode.com/users"

# %%
page = requests.get(data_json)

# %%
output = page.json()

# %%
# save file data.json
with open('data.json', 'w') as dt:
  json.dump(output, dt)

# membaca file data.json
with open('data.json', 'r') as out:
  page = json.load(out)

# menampilkan 5 daftar data.json berisikan email
for i in range(5):
  print(page[i]['email'])
# Out:
# Sincere@april.biz
# Shanna@melissa.tv
# Nathan@yesenia.net
# Julianne.OConner@kory.org
# Lucio_Hettinger@annie.ca

# %%
# kita export kedalam file extensi .xlsx
pd.read_json('data.json').to_csv('data.csv')

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0  id              name   username                      email  \
# 0           0   1     Leanne Graham       Bret          Sincere@april.biz
# 1           1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2           2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3           3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4           4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
# ...
