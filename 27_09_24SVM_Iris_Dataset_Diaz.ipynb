# %% [markdown]
# <a href="https://colab.research.google.com/github/yasnilamw/MSIB-K2-KelasAwanPintar/blob/main/27_09_24SVM_Iris_Dataset_Diaz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **REMINDER**
# Sebelum memulai pembelajaran self-learning jangan lupa berdoa ya teman-teman dan perhatikan:
# 1. Jika menggunakan Jupyter Notebook, silahkan pilih "File" --> "Download" --> "Download .ipynb"
# 2. Jika menggunakan Colab, silahkan pilih "File" --> "Save a copy in drive"

# %% [markdown]
# ## Klasifikasi Iris Dataset menggunakan SVM

# %% [markdown]
# Pada modul kali ini, kita akan melakukan klasifikasi untuk dataset iris dengan menggunakan algoritma Support Vector Machine (SVM). Adapun prediksi didasarkan pada fitur/karakteristik dari bunga Iris, yaitu: Sepal Length, Sepal Width, Petal Length, Petal Width yang sudah memiliki kelas (species). Kelasnya adalah iris-setosa, iris-virginica, iris-versicolor.

# %% [markdown]
# # **MODUL SVM**

# %% [markdown]
# ## 1. Impor Library/Package

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## 2. Load Dataset

# %% [markdown]
# Dataset yang digunakan masih dataset Iris, hanya saja sekarang akan langsung mengakses dari UCI MACHINE LEARNING REPOSITORY.

# %%
#Read the dataset
dataframeasli = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data" )

#Data
dataframeasli.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['5.1'].plot(kind='hist', bins=20, title='5.1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['3.5'].plot(kind='hist', bins=20, title='3.5')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['1.4'].plot(kind='hist', bins=20, title='1.4')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['0.2'].plot(kind='hist', bins=20, title='0.2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='5.1', y='3.5', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='3.5', y='1.4', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='1.4', y='0.2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['0.2']
#   ys = series['5.1']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('0.2', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('0.2')
# _ = plt.ylabel('5.1')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['0.2']
#   ys = series['3.5']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('0.2', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('0.2')
# _ = plt.ylabel('3.5')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['0.2']
#   ys = series['1.4']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('0.2', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('0.2')
# _ = plt.ylabel('1.4')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['0.2']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': '0.2'}, axis=1)
#               .sort_values('0.2', ascending=True))
#   xs = counted['0.2']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('0.2', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('0.2')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['5.1'].plot(kind='line', figsize=(8, 4), title='5.1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['3.5'].plot(kind='line', figsize=(8, 4), title='3.5')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['1.4'].plot(kind='line', figsize=(8, 4), title='1.4')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['0.2'].plot(kind='line', figsize=(8, 4), title='0.2')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# Dataset ini tidak memiliki nama kolom apapun. Jadi, pertama-tama kita akan mendefinisikan nama kolom dan membaca data yang ada.

# %%
#Mendefinisikan nama kolom data
colnames=["sepal_length_in_cm", "sepal_width_in_cm","petal_length_in_cm","petal_width_in_cm", "class"]

#Read the dataset
dataframe = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", header = None, names= colnames )

#Data
dataframe.head()
# Out:
#    sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal_width_in_cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['sepal_length_in_cm'].plot(kind='hist', bins=20, title='sepal_length_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['sepal_width_in_cm'].plot(kind='hist', bins=20, title='sepal_width_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['petal_length_in_cm'].plot(kind='hist', bins=20, title='petal_length_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='sepal_length_in_cm', y='sepal_width_in_cm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='sepal_width_in_cm', y='petal_length_in_cm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['petal_width_in_cm']
#   ys = series['sepal_length_in_cm']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_20.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('sepal_length_in_cm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['petal_width_in_cm']
#   ys = series['sepal_width_in_cm']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_21.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('sepal_width_in_cm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['petal_width_in_cm']
#   ys = series['petal_length_in_cm']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('petal_length_in_cm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['petal_width_in_cm']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'petal_width_in_cm'}, axis=1)
#               .sort_values('petal_width_in_cm', ascending=True))
#   xs = counted['petal_width_in_cm']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_23.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['sepal_length_in_cm'].plot(kind='line', figsize=(8, 4), title='sepal_length_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['sepal_width_in_cm'].plot(kind='line', figsize=(8, 4), title='sepal_width_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['petal_length_in_cm'].plot(kind='line', figsize=(8, 4), title='petal_length_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Terdapat kolom kategorikal pada class, sehingga harus dilakukan encoding untuk mengubahnya menjadi nilai numerik.

# %%
#Encoding the categorical column
dataframe = dataframe.replace({"class":  {"Iris-setosa":1,"Iris-versicolor":2, "Iris-virginica":3}})
#Visualize the new dataset
dataframe.head()
# Out:
#    sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal_width_in_cm  class
# 0                0.2      1
# 1                0.2      1
# 2                0.2      1
# 3                0.2      1
# 4                0.2      1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['sepal_length_in_cm'].plot(kind='hist', bins=20, title='sepal_length_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['sepal_width_in_cm'].plot(kind='hist', bins=20, title='sepal_width_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['petal_length_in_cm'].plot(kind='hist', bins=20, title='petal_length_in_cm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='sepal_length_in_cm', y='sepal_width_in_cm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_31.plot(kind='scatter', x='sepal_width_in_cm', y='petal_length_in_cm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['petal_width_in_cm']
#   ys = series['sepal_length_in_cm']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('sepal_length_in_cm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['petal_width_in_cm']
#   ys = series['sepal_width_in_cm']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('sepal_width_in_cm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['petal_width_in_cm']
#   ys = series['petal_length_in_cm']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('petal_length_in_cm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['petal_width_in_cm']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'petal_width_in_cm'}, axis=1)
#               .sort_values('petal_width_in_cm', ascending=True))
#   xs = counted['petal_width_in_cm']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('petal_width_in_cm', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('petal_width_in_cm')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36['sepal_length_in_cm'].plot(kind='line', figsize=(8, 4), title='sepal_length_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['sepal_width_in_cm'].plot(kind='line', figsize=(8, 4), title='sepal_width_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['petal_length_in_cm'].plot(kind='line', figsize=(8, 4), title='petal_length_in_cm')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#Visualisasi dataframe
plt.figure(1)
sns.heatmap(dataframe.corr())
plt.title('Correlation On iris Classes')
# Out:
# Text(0.5, 1.0, 'Correlation On iris Classes')

# %% [markdown]
# ## 4. Pemisahan data Training dan Testing

# %%
X = dataframe.iloc[:,:-1] #X = memilih semua fitur kecuali kolom terakhir
y = dataframe.iloc[:, -1].values #y = memilih target yaitu kolom terakhir

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## 5. Modelling Data

# %%
#Membangun model SVM
classifier = SVC(kernel = 'linear', random_state = 0)

#Fit model SVM ke data
classifier.fit(X_train, y_train)

#Membuat prediksi
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## 6. Evaluasi Model SVM menggunakan metrices Accuracy

# %%
#Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

#Evaluasi performa model dengan accuracy
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]
# Accuracy: 98.18 %

# %% [markdown]
# Diperoleh akurasi sebesar 98 %, dimana kinerja model berarti sangat baik. Serta berdasarkan confusion matrix yang dihasilkan, terlihat hanya ada satu kesalahan klasifikasi data(one misclassified data).

# %% [markdown]
# That's it! Teman-teman sudah berhasil melakukan klasifikasi sederhana menggunakan SVM terhadap spesies tumbuhan Iris.
